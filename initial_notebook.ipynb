# %%
import os
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import fetch_lfw_pairs

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten

# %%
if not os.path.exists('data'):
    os.makedirs('data')
else:
    print('data Folder already exists')



folders = ['data/anchor' ,'data/positive', 'data/negative']

for folder in folders:
    if not os.path.exists(folder):
        os.makedirs(folder)
    else:
        print(f'{folder} Folder already exists')
# Out:
# data Folder already exists
# data/anchor Folder already exists
# data/positive Folder already exists
# data/negative Folder already exists

# %%
lfw_pairs_train = fetch_lfw_pairs(subset='train', resize=1, color=True)
lfw_pairs_test = fetch_lfw_pairs(subset='test', resize=1, color=True)

# %%
positive_pairs_train = lfw_pairs_train.pairs[lfw_pairs_train.target == 1]
negative_pairs_train = lfw_pairs_train.pairs[lfw_pairs_train.target == 0]

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(4, 6))

random_index = np.random.randint(0, len(positive_pairs_train), 3)

for i, index in enumerate(random_index):
    plt.suptitle('Positive Pairs', fontsize=20)
    anchor, positive = positive_pairs_train[index]
    ax[i, 0].imshow(anchor, aspect='auto')
    ax[i, 0].axis('off')
    ax[i, 1].imshow(positive, aspect='auto')
    ax[i, 1].axis('off')

plt.show()

# %%
fig, ax = plt.subplots(nrows=3, ncols=2, figsize=(4, 6))

for i, index in enumerate(random_index):

    plt.suptitle('Negative Pairs', fontsize=20)
    neg_1, neg_2 = negative_pairs_train[index]
    ax[i, 0].imshow(neg_1, aspect='auto')
    ax[i, 0].axis('off')
    ax[i, 1].imshow(neg_2, aspect='auto')
    ax[i, 1].axis('off')

plt.show()
